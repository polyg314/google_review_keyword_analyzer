# %%
import requests
import re
import os
from dotenv import load_dotenv

# Load SerpAPI key from .env
load_dotenv()
serpapi_key = os.getenv("SERPAPI_KEY")

# %%
def extract_data_id_from_url(url: str) -> str:
    """
    Extracts the Google Maps data_id from a full Google Maps URL.
    Looks for pattern: !1s0x...:0x...
    """
    decoded = re.sub(r"%2F|%2f", "/", url)
    match = re.search(r"!1s(0x[0-9a-f]+:0x[0-9a-f]+)", decoded)
    return match.group(1) if match else None


def fetch_reviews_by_data_id(data_id: str, max_reviews: int = 100, sort_by: str = "newestFirst", lang: str = "en"):
    """
    Fetches up to `max_reviews` Google Maps reviews using SerpAPI.
    Handles pagination with next_page_token.
    """
    base_url = "https://serpapi.com/search.json"
    all_reviews = []
    page_token = None
    page = 0

    while len(all_reviews) < max_reviews:
        params = {
            "engine": "google_maps_reviews",
            "data_id": data_id,
            "api_key": serpapi_key,
            "hl": lang,
            "sort_by": sort_by,
        }

        # Only use num and next_page_token on follow-up pages
        if page_token:
            params["next_page_token"] = page_token
            params["num"] = 20  # Max allowed per follow-up page

        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()

        new_reviews = data.get("reviews", [])
        all_reviews.extend(new_reviews)

        # Break if no more pages
        page_token = data.get("serpapi_pagination", {}).get("next_page_token")
        if not page_token:
            break

        page += 1

    return all_reviews[:max_reviews]

# %%
maps_url = "https://www.google.com/maps/place/Safeway/@45.4281317,-122.5607997,14z/data=!4m8!3m7!1s0x54959e215df5e1b7:0x524bf6f735f45390!8m2!3d45.428135!4d-122.5401986!9m1!1b1!16s%2Fg%2F1w455b36?entry=ttu"
data_id = extract_data_id_from_url(maps_url)
print("✅ Extracted data_id:", data_id)

if data_id:
    reviews = fetch_reviews_by_data_id(data_id, max_reviews=100, sort_by="newestFirst")
    print(f"\n📄 Retrieved {len(reviews)} reviews")

    for i, r in enumerate(reviews[:5], 1):
        print(f"\n{i}. ⭐ {r.get('rating')} — {r.get('date')}")
        print(r.get('snippet', '(no text)'))
else:
    print("❌ Could not extract data_id from URL.")
# Out:
# ✅ Extracted data_id: 0x54959e215df5e1b7:0x524bf6f735f45390
#
# 📄 Retrieved 100 reviews
#
# 1. ⭐ 5.0 — a week ago
# (no text)
#
# 2. ⭐ 3.0 — a week ago
# (no text)
#
# 3. ⭐ 4.0 — 2 weeks ago
# (no text)
#
# 4. ⭐ 5.0 — 3 weeks ago
# Nice place to visit and meet people. The food is excellent, but just know that they want you to purchase it before you eat it.
#
# 5. ⭐ 5.0 — 3 weeks ago
# (no text)

# %%
len(reviews)
# Out:
# 100

# %%
reviews
# Out:
# [{'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnTURJaEpTZ3lnRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDIhJSgygE%7CCgwIyIPNvwYQwKe71QM%7C?hl=en-US',
#   'rating': 5.0,
#   'date': 'a week ago',
#   'iso_date': '2025-04-07T03:08:56Z',
#   'iso_date_of_last_edit': '2025-04-07T03:08:56Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnTURJaEpTZ3lnRRAB',
#   'user': {'name': 'iva martinez',
#    'link': 'https://www.google.com/maps/contrib/106887247089577412636?hl=en-US',
#    'contributor_id': '106887247089577412636',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjWAT1fOQ0-UT33Me-HSpXLXFJUphjbqWT7TGqa93u1bxyDl5ktZEw=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 13,
#    'photos': 220},
#   'response': {'date': 'a week ago',
#    'iso_date': '2025-04-07T03:19:16Z',
#    'iso_date_of_last_edit': '2025-04-07T03:19:16Z',
#    'snippet': "Hello iva martinez, thank you for the 5 star review! We're committed to providing outstanding service.",
#    'extracted_snippet': {'original': "Hello iva martinez, thank you for the 5 star review! We're committed to providing outstanding service."}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnTUNJLTlQZDJnRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMCI-9Pd2gE%7CCgwIwJPCvwYQ8Oj6twM%7C?hl=en-US',
#   'rating': 3.0,
#   'date': 'a week ago',
#   'iso_date': '2025-04-05T01:39:12Z',
#   'iso_date_of_last_edit': '2025-04-05T01:39:12Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnTUNJLTlQZDJnRRAB',
#   'user': {'name': 'dano downing',
#    'link': 'https://www.google.com/maps/contrib/103943491000907297884?hl=en-US',
#    'contributor_id': '103943491000907297884',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocI8A3OxxO0ppYlzIgRxLz6krH20odinZXQo_KNx3NQiq87CNg=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 1,
#    'photos': 0},
#   'response': {'date': 'a week ago',
#    'iso_date': '2025-04-05T03:17:42Z',
#    'iso_date_of_last_edit': '2025-04-05T03:17:42Z',
#    'snippet': "Hello dano downing, we're sorry to see your 3 star review. We would love the opportunity to improve your experience. Please contact us at https://www.albertsons.com/inquiry/contact-us.html.",
#    'extracted_snippet': {'original': "Hello dano downing, we're sorry to see your 3 star review. We would love the opportunity to improve your experience. Please contact us at https://www.albertsons.com/inquiry/contact-us.html."}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTUR3al9yX0p3EAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDwj_r_Jw%7CCgsIwpOdvwYQsJroLA%7C?hl=en-US',
#   'rating': 4.0,
#   'date': '2 weeks ago',
#   'iso_date': '2025-03-29T01:15:46Z',
#   'iso_date_of_last_edit': '2025-03-29T01:15:46Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnTUR3al9yX0p3EAE',
#   'user': {'name': 'keung c',
#    'link': 'https://www.google.com/maps/contrib/101397333372112664324?hl=en-US',
#    'contributor_id': '101397333372112664324',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjW6ShSYebH1pzWro4ARPFs0d_T2nuGW4YjJnVhgYqmxmLMuwk8=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 0,
#    'photos': 0},
#   'response': {'date': '2 weeks ago',
#    'iso_date': '2025-03-29T15:57:59Z',
#    'iso_date_of_last_edit': '2025-03-29T15:57:59Z',
#    'snippet': 'Hello keung c, we appreciate your 4 star review and look forward to serving you again!',
#    'extracted_snippet': {'original': 'Hello keung c, we appreciate your 4 star review and look forward to serving you again!'}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTUR3eGNTTllnEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDwxcSNYg%7CCgsIn4-TvwYQiKCKNQ%7C?hl=en-US',
#   'rating': 5.0,
#   'date': '3 weeks ago',
#   'iso_date': '2025-03-27T03:35:59Z',
#   'iso_date_of_last_edit': '2025-03-27T03:35:59Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnTUR3eGNTTllnEAE',
#   'user': {'name': 'Linzey Green',
#    'link': 'https://www.google.com/maps/contrib/103701385354738945216?hl=en-US',
#    'contributor_id': '103701385354738945216',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocLYzJex5MU5M1zIcdAtVkryhzxjKjoRptYZGtvdohC1wVgKdA=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 8,
#    'photos': 0},
#   'snippet': 'Nice place to visit and meet people. The food is excellent, but just know that they want you to purchase it before you eat it.',
#   'extracted_snippet': {'original': 'Nice place to visit and meet people. The food is excellent, but just know that they want you to purchase it before you eat it.'},
#   'response': {'date': '2 weeks ago',
#    'iso_date': '2025-03-28T12:42:40Z',
#    'iso_date_of_last_edit': '2025-03-28T12:42:40Z',
#    'snippet': "Hi Linzey! Thank you for the great review! 😊 We're so glad to hear you enjoy the food and the atmosphere. And yes, we appreciate your understanding of the store's policies! We look forward to welcoming you again soon! 🌟",
#    'extracted_snippet': {'original': "Hi Linzey! Thank you for the great review! 😊 We're so glad to hear you enjoy the food and the atmosphere. And yes, we appreciate your understanding of the store's policies! We look forward to welcoming you again soon! 🌟"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTUR3eWRfRWZ3EAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDwyd_Efw%7CCgwIlqWRvwYQsKCevgI%7C?hl=en-US',
#   'rating': 5.0,
#   'date': '3 weeks ago',
#   'iso_date': '2025-03-26T19:16:38Z',
#   'iso_date_of_last_edit': '2025-03-26T19:16:38Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnTUR3eWRfRWZ3EAE',
#   'user': {'name': 'Sarah Delaney',
#    'link': 'https://www.google.com/maps/contrib/113324184518282092043?hl=en-US',
#    'contributor_id': '113324184518282092043',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocL3x6dQrfXsxh10ufIYqI87SC4Pr9wkgh7rdCSe_1IbHOOd9Q=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 3,
#    'photos': 2},
#   'response': {'date': '3 weeks ago',
#    'iso_date': '2025-03-27T01:03:03Z',
#    'iso_date_of_last_edit': '2025-03-27T01:03:03Z',
#    'snippet': "Thank you for your 5 star review, Sarah Delaney! We're thrilled to see you had a positive experience!",
#    'extracted_snippet': {'original': "Thank you for your 5 star review, Sarah Delaney! We're thrilled to see you had a positive experience!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTURRcDg2RGNBEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDQp86DcA%7CCgwInOzSvgYQkKzOyAE%7C?hl=en-US',
#   'rating': 5.0,
#   'date': 'a month ago',
#   'iso_date': '2025-03-14T22:59:33Z',
#   'iso_date_of_last_edit': '2025-03-14T23:05:00Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnTURRcDg2RGNBEAE',
#   'user': {'name': 'Tyson',
#    'link': 'https://www.google.com/maps/contrib/105504789338304226531?hl=en-US',
#    'contributor_id': '105504789338304226531',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjVGVs9R6Od1hMEX6Sjz3yZX6MG9nyTergwq_vqL5r2Lc4GVU2s=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 2,
#    'photos': 1},
#   'snippet': 'Positive Vibe on Natural',
#   'extracted_snippet': {'original': 'Positive Vibe on Natural'},
#   'response': {'date': 'a month ago',
#    'iso_date': '2025-03-16T01:23:15Z',
#    'iso_date_of_last_edit': '2025-03-16T01:23:15Z',
#    'snippet': 'Hi Tyson! Thank you for your 5-star review. We appreciate you for sharing your feedback regarding the store appearance. Your concerns have been brought to our team\'s attention, as your feedback is very important to us. We are committed to ensuring our customers\' shopping experience is both seamless and enjoyable. This positive feedback has been forwarded to the Safeway Store in Clackamas, OR. For further assistance, please visit the "Contact Us" page on our official website, include your phone number, and reference this Google review. Thank you.',
#    'extracted_snippet': {'original': 'Hi Tyson! Thank you for your 5-star review. We appreciate you for sharing your feedback regarding the store appearance. Your concerns have been brought to our team\'s attention, as your feedback is very important to us. We are committed to ensuring our customers\' shopping experience is both seamless and enjoyable. This positive feedback has been forwarded to the Safeway Store in Clackamas, OR. For further assistance, please visit the "Contact Us" page on our official website, include your phone number, and reference this Google review. Thank you.'}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUN3bkllMGFnEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICwnIe0ag%7CCgwI2_zMvgYQgIrSowI%7C?hl=en-US',
#   'rating': 5.0,
#   'date': 'a month ago',
#   'iso_date': '2018-09-01T04:26:46Z',
#   'iso_date_of_last_edit': '2025-03-13T20:21:47Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUN3bkllMGFnEAE',
#   'user': {'name': 'Jr. Velasquez',
#    'link': 'https://www.google.com/maps/contrib/106631455003042455650?hl=en-US',
#    'contributor_id': '106631455003042455650',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjWxipKmGZ-wYz5gR3YZU4Kf25MEVkBF1Z77ph8pg8XhDsnxuupl=s120-c-rp-mo-ba6-br100',
#    'local_guide': True,
#    'reviews': 679,
#    'photos': 2136},
#   'snippet': "It's Safeway",
#   'extracted_snippet': {'original': "It's Safeway"}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTURRMXViS1VnEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDQ1ubKUg%7CCgwIh4K-vgYQqNjugAE%7C?hl=en-US',
#   'rating': 5.0,
#   'date': 'a month ago',
#   'iso_date': '2025-03-11T00:17:11Z',
#   'iso_date_of_last_edit': '2025-03-11T00:17:11Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnTURRMXViS1VnEAE',
#   'user': {'name': 'Being Matsu',
#    'link': 'https://www.google.com/maps/contrib/110307886508265575738?hl=en-US',
#    'contributor_id': '110307886508265575738',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocIsEWOYr0DBU93F1DQMCjuIMVOZKsATx2EUG0_Y87LWtFBtqA=s120-c-rp-mo-ba2-br100',
#    'local_guide': True,
#    'reviews': 3,
#    'photos': 2},
#   'response': {'date': 'a month ago',
#    'iso_date': '2025-03-11T16:30:38Z',
#    'iso_date_of_last_edit': '2025-03-11T16:30:38Z',
#    'snippet': 'Hi Being Matsu, thank you for your 5 star review! We value your input and support. ',
#    'extracted_snippet': {'original': 'Hi Being Matsu, thank you for your 5 star review! We value your input and support. '}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnTUNRMnJTUjF3RRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMCQ2rSR1wE%7CCgwI5OqXvgYQyMWSvQI%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a month ago',
#   'iso_date': '2025-03-03T18:31:00Z',
#   'iso_date_of_last_edit': '2025-03-03T18:31:00Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnTUNRMnJTUjF3RRAB',
#   'user': {'name': 'Stephanie Morgan',
#    'link': 'https://www.google.com/maps/contrib/111276564202097362986?hl=en',
#    'contributor_id': '111276564202097362986',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjVg0SnbZ7eAyu7MzP2LYC3jHkTYcYt8AwtEcZF-Cn3B47FbB4NU=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 34,
#    'photos': 0},
#   'response': {'date': 'a month ago',
#    'iso_date': '2025-03-04T12:21:44Z',
#    'iso_date_of_last_edit': '2025-03-04T12:21:44Z',
#    'snippet': 'Hi Stephanie Morgan, thank you for your 5 star review! We value your input and support. ',
#    'extracted_snippet': {'original': 'Hi Stephanie Morgan, thank you for your 5 star review! We value your input and support. '}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTURnN19lM0h3EAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDg7_e3Hw%7CCgwIgNiHvgYQuM6V3wE%7C?hl=en',
#   'rating': 4.0,
#   'date': 'a month ago',
#   'iso_date': '2025-02-28T17:01:52Z',
#   'iso_date_of_last_edit': '2025-02-28T17:01:52Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnTURnN19lM0h3EAE',
#   'user': {'name': 'Andreea Capusan',
#    'link': 'https://www.google.com/maps/contrib/104061657515777654808?hl=en',
#    'contributor_id': '104061657515777654808',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocJVHgvrjPTF2_q8rva5yF-28S3Fbnr6UDO4tASIQIv5XV07rQ=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 3,
#    'photos': 2},
#   'response': {'date': 'a month ago',
#    'iso_date': '2025-02-28T21:28:14Z',
#    'iso_date_of_last_edit': '2025-02-28T21:28:14Z',
#    'snippet': "Thank you for your 4 star review, Andreea Capusan! We're glad to know we met your expectations.",
#    'extracted_snippet': {'original': "Thank you for your 4 star review, Andreea Capusan! We're glad to know we met your expectations."}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTURncGFpLURREAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDgpai-DQ%7CCgwIja_6vQYQ-OTV1gM%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a month ago',
#   'iso_date': '2025-02-26T04:24:45Z',
#   'iso_date_of_last_edit': '2025-02-26T04:24:45Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnTURncGFpLURREAE',
#   'user': {'name': 'Vadim Savetskiy',
#    'link': 'https://www.google.com/maps/contrib/112731762983082780931?hl=en',
#    'contributor_id': '112731762983082780931',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUm_7pzIb9_dl3AP2BeMcOATla1My00k997S02ZPbQOsArMhE0Y=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 69,
#    'photos': 287},
#   'response': {'date': 'a month ago',
#    'iso_date': '2025-02-27T01:53:04Z',
#    'iso_date_of_last_edit': '2025-02-27T01:53:04Z',
#    'snippet': "Thank you for your 5 star review, Vadim Savetskiy! We're thrilled to see you had a positive experience!",
#    'extracted_snippet': {'original': "Thank you for your 5 star review, Vadim Savetskiy! We're thrilled to see you had a positive experience!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnTURncXRIaHNnRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDgqtHhsgE%7CCgwIucbvvQYQyIalkQM%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a month ago',
#   'iso_date': '2025-02-24T03:10:49Z',
#   'iso_date_of_last_edit': '2025-02-24T03:10:49Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnTURncXRIaHNnRRAB',
#   'user': {'name': 'Christina Santiago',
#    'link': 'https://www.google.com/maps/contrib/105122659735069166823?hl=en',
#    'contributor_id': '105122659735069166823',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUaenCr1ZQBnYsY5nkTi3Db_20OJMhBjPOFCdDD98D1gpK7qaE=s120-c-rp-mo-ba2-br100',
#    'local_guide': True,
#    'reviews': 14,
#    'photos': 14},
#   'response': {'date': 'a month ago',
#    'iso_date': '2025-02-24T09:23:29Z',
#    'iso_date_of_last_edit': '2025-02-24T09:23:29Z',
#    'snippet': 'Hello Christina Santiago, thank you for recognizing our dedication to providing excellent service! We appreciate your feedback and for posting a 5 star review!',
#    'extracted_snippet': {'original': 'Hello Christina Santiago, thank you for recognizing our dedication to providing excellent service! We appreciate your feedback and for posting a 5 star review!'}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTUNncHNia1FREAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMCgpsbkQQ%7CCgwIw9LIvQYQgJv8oQI%7C?hl=en',
#   'rating': 4.0,
#   'date': '2 months ago',
#   'iso_date': '2025-02-16T18:06:59Z',
#   'iso_date_of_last_edit': '2025-02-16T18:06:59Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnTUNncHNia1FREAE',
#   'user': {'name': 'Adam Rolin',
#    'link': 'https://www.google.com/maps/contrib/102423544533342944617?hl=en',
#    'contributor_id': '102423544533342944617',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjU-IFg07d_9A7BK1FYm1dU4DxrlBXJGbnGoTDuv0mr9zwxmGPo=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 14,
#    'photos': 100},
#   'response': {'date': '2 months ago',
#    'iso_date': '2025-02-17T03:54:58Z',
#    'iso_date_of_last_edit': '2025-02-17T03:54:58Z',
#    'snippet': "Hello Adam Rolin, thank you for your 4 star review! Your feedback means a lot to us! We're happy we could meet your expectations and provide a great shopping experience!",
#    'extracted_snippet': {'original': "Hello Adam Rolin, thank you for your 4 star review! Your feedback means a lot to us! We're happy we could meet your expectations and provide a great shopping experience!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURTeWVtdnBBRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDSyemvpAE%7CCgwIiYqtvQYQ6MChvAI%7C?hl=en',
#   'rating': 5.0,
#   'date': '2 months ago',
#   'iso_date': '2020-12-30T20:31:02Z',
#   'iso_date_of_last_edit': '2025-02-11T12:39:37Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURTeWVtdnBBRRAB',
#   'user': {'name': 'Brian Roth',
#    'link': 'https://www.google.com/maps/contrib/103606638292248047551?hl=en',
#    'contributor_id': '103606638292248047551',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUIpWDcSdoApMlcmZnjFm_5Rr_85-TCgzkFxgfJbOd0QFdfjeow=s120-c-rp-mo-ba5-br100',
#    'local_guide': True,
#    'reviews': 412,
#    'photos': 93},
#   'snippet': 'Very busy store.  Good friday chicken.',
#   'extracted_snippet': {'original': 'Very busy store.  Good friday chicken.'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTURBM2VTX1pBEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDA3eS_ZA%7CCgsIzISsvQYQ0JybOw%7C?hl=en',
#   'rating': 5.0,
#   'date': '2 months ago',
#   'iso_date': '2025-02-11T07:54:52Z',
#   'iso_date_of_last_edit': '2025-02-11T07:54:52Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnTURBM2VTX1pBEAE',
#   'user': {'name': 'Kathy Rankin',
#    'link': 'https://www.google.com/maps/contrib/114310437533788525703?hl=en',
#    'contributor_id': '114310437533788525703',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUzLKgF4e39wfCW3mIuwOuW0GkoCfPYKelf5hXJdtBMouD3dy_plg=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 44,
#    'photos': 18},
#   'snippet': "Safeway's in pretty little bit in the last few months. I've learned how to use their app and check the receipt for the cause sometimes the checkers will add twice when you only purchase one item but they've been better lately",
#   'extracted_snippet': {'original': "Safeway's in pretty little bit in the last few months. I've learned how to use their app and check the receipt for the cause sometimes the checkers will add twice when you only purchase one item but they've been better lately"}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnTURBOW9fTzBRRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDA9o_O0QE%7CCgwIvNafvQYQ2PHFlAI%7C?hl=en',
#   'rating': 4.0,
#   'date': '2 months ago',
#   'iso_date': '2025-02-08T23:39:40Z',
#   'iso_date_of_last_edit': '2025-02-08T23:39:40Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnTURBOW9fTzBRRRAB',
#   'user': {'name': 'Benjamin Hayes',
#    'link': 'https://www.google.com/maps/contrib/108425221904854000422?hl=en',
#    'contributor_id': '108425221904854000422',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocL1vkWJaOOHDYhdP_1OU-VZmDk97yf2aHxfeRtRM3Mq5EStjA=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 10,
#    'photos': 1},
#   'response': {'date': '2 months ago',
#    'iso_date': '2025-02-09T01:10:15Z',
#    'iso_date_of_last_edit': '2025-02-09T01:10:15Z',
#    'snippet': "Hello Benjamin Hayes, your 4 star review and positive feedback is greatly appreciated! We're committed to providing excellent customer service and products!",
#    'extracted_snippet': {'original': "Hello Benjamin Hayes, your 4 star review and positive feedback is greatly appreciated! We're committed to providing excellent customer service and products!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnTURBNEtuaXVBRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgMDA4KniuAE%7CCgwIy5aRvQYQ6Mmy3wI%7C?hl=en',
#   'rating': 4.0,
#   'date': '2 months ago',
#   'iso_date': '2025-02-06T05:40:27Z',
#   'iso_date_of_last_edit': '2025-02-06T05:40:27Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnTURBNEtuaXVBRRAB',
#   'user': {'name': 'Tammy Wood',
#    'link': 'https://www.google.com/maps/contrib/108994363682706858715?hl=en',
#    'contributor_id': '108994363682706858715',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocLgxH6dG72oFwGQqIzQNVGlJFbPn0nh2Y7luajsdD1-XbdhvNA=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 74,
#    'photos': 21},
#   'snippet': 'The store was clean and organized.  Friendly staff.  I even ask directions and was told exactly how to get there and he was very nice about explaining it.',
#   'extracted_snippet': {'original': 'The store was clean and organized.  Friendly staff.  I even ask directions and was told exactly how to get there and he was very nice about explaining it.'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURmN283OWZnEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDf7o79fg%7CCgsI-buOvQYQkKvjUg%7C?hl=en',
#   'rating': 5.0,
#   'date': '2 months ago',
#   'iso_date': '2025-01-06T19:19:34Z',
#   'iso_date_of_last_edit': '2025-02-05T17:20:57Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURmN283OWZnEAE',
#   'user': {'name': 'Daniel Soto',
#    'link': 'https://www.google.com/maps/contrib/104951171146606430214?hl=en',
#    'contributor_id': '104951171146606430214',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjWCJqrs_Nnmpg9K_7cTJXH8_7SHnXCX52F90_Xwq5dlKfGqU2Dx=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 140,
#    'photos': 1},
#   'snippet': 'like it',
#   'extracted_snippet': {'original': 'like it'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURmMmZtcnlnRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDf2fmrygE%7CCgwInbL4uwYQyKPUkgE%7C?hl=en',
#   'rating': 5.0,
#   'date': '3 months ago',
#   'iso_date': '2025-01-08T06:20:13Z',
#   'iso_date_of_last_edit': '2025-01-08T06:20:13Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURmMmZtcnlnRRAB',
#   'user': {'name': 'Jan E',
#    'link': 'https://www.google.com/maps/contrib/109030137211661521866?hl=en',
#    'contributor_id': '109030137211661521866',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjVGLmCd_EwPuGifSJxjJLQ-bun6x0bNq1YYHVZnKiHa_47k-sPs=s120-c-rp-mo-ba3-br100',
#    'local_guide': True,
#    'reviews': 38,
#    'photos': 1},
#   'snippet': 'When I moved in neighborhood, I felt so welcome by Safeway employees. The manager came to help me quickly sign back up. The store is clean and always in stock. I don\'t think I\'ve seen them be out of things, even the "sale" items. Love the discount ,dropping the price right down to a good deal. Love this store for every thing listed , yet biggest credit to friendly & awesome employees.',
#   'extracted_snippet': {'original': 'When I moved in neighborhood, I felt so welcome by Safeway employees. The manager came to help me quickly sign back up. The store is clean and always in stock. I don\'t think I\'ve seen them be out of things, even the "sale" items. Love the discount ,dropping the price right down to a good deal. Love this store for every thing listed , yet biggest credit to friendly & awesome employees.'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNmMjRqVUFnEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICf24jUAg%7CCgwIm-LWuwYQ4LiuzQM%7C?hl=en',
#   'rating': 5.0,
#   'date': '3 months ago',
#   'iso_date': '2025-01-01T21:18:19Z',
#   'iso_date_of_last_edit': '2025-01-01T21:18:19Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUNmMjRqVUFnEAE',
#   'user': {'name': 'Robert Dolton',
#    'link': 'https://www.google.com/maps/contrib/105883860138766722292?hl=en',
#    'contributor_id': '105883860138766722292',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocKJTNQXnL0gkk0uZal1XfIDtmzSbfTV8vnAY7CPrc31YDD6=s120-c-rp-mo-br100',
#    'reviews': 2,
#    'photos': 0},
#   'snippet': 'Really nice folks work there. It is a small store but they have excellent selection. Produce is good quality.',
#   'extracted_snippet': {'original': 'Really nice folks work there. It is a small store but they have excellent selection. Produce is good quality.'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNmanVidlNREAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICfjubvSQ%7CCgwItODCuwYQgLS5gAE%7C?hl=en',
#   'rating': 5.0,
#   'date': '3 months ago',
#   'iso_date': '2024-12-29T02:13:08Z',
#   'iso_date_of_last_edit': '2024-12-29T02:13:08Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUNmanVidlNREAE',
#   'user': {'name': 'B S',
#    'link': 'https://www.google.com/maps/contrib/106148481483189113068?hl=en',
#    'contributor_id': '106148481483189113068',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjVlFRd9ZeiQCxIhYhc675TBuB6U7OvUkOQAO4Q1z4bQDYIcxRwGHg=s120-c-rp-mo-ba5-br100',
#    'local_guide': True,
#    'reviews': 644,
#    'photos': 918},
#   'snippet': "Great place to eat Great burgers it's only in seattle, so if you're in seattle, you gotta give it a try",
#   'extracted_snippet': {'original': "Great place to eat Great burgers it's only in seattle, so if you're in seattle, you gotta give it a try"}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUNmaXFQU2t3RRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICfiqPSkwE%7CCgwIqce8uwYQ2KyxyQM%7C?hl=en',
#   'rating': 5.0,
#   'date': '3 months ago',
#   'iso_date': '2024-12-27T22:01:13Z',
#   'iso_date_of_last_edit': '2024-12-27T22:01:13Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUNmaXFQU2t3RRAB',
#   'user': {'name': 'Marc Robillard',
#    'link': 'https://www.google.com/maps/contrib/105997272268681350391?hl=en',
#    'contributor_id': '105997272268681350391',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjU1dtZLbz1N7PJocoVpkoR9WMUZ7aciHSTzj-tKWeiiM2mKN7D3=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 28,
#    'photos': 110},
#   'response': {'date': '3 months ago',
#    'iso_date': '2024-12-28T20:43:15Z',
#    'iso_date_of_last_edit': '2024-12-28T20:43:15Z',
#    'snippet': "Hello Marc Robillard, thank you for sharing your experience with us and for the 5 star review! We're grateful for your feedback and hope to serve you again soon!",
#    'extracted_snippet': {'original': "Hello Marc Robillard, thank you for sharing your experience with us and for the 5 star review! We're grateful for your feedback and hope to serve you again soon!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNmakxDcUlREAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICfjLCqIQ%7CCgwIg_O1uwYQgODQqwE%7C?hl=en',
#   'rating': 5.0,
#   'date': '3 months ago',
#   'iso_date': '2024-12-26T15:42:59Z',
#   'iso_date_of_last_edit': '2024-12-26T15:42:59Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUNmakxDcUlREAE',
#   'user': {'name': 'Michael Scott',
#    'link': 'https://www.google.com/maps/contrib/117244228488154906797?hl=en',
#    'contributor_id': '117244228488154906797',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjWpeZ87ubZ0U9RzQnUX7prcZKfcR4ZFh9HrX72YUK9fe_Zh7PpK=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 3,
#    'photos': 0},
#   'response': {'date': '3 months ago',
#    'iso_date': '2024-12-26T21:03:07Z',
#    'iso_date_of_last_edit': '2024-12-26T21:03:07Z',
#    'snippet': "Hello Michael Scott, thank you for sharing your experience with us and for the 5 star review! We're grateful for your feedback and hope to serve you again soon!",
#    'extracted_snippet': {'original': "Hello Michael Scott, thank you for sharing your experience with us and for the 5 star review! We're grateful for your feedback and hope to serve you again soon!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUR2LVotajF3RRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDv-Z-j1wE%7CCgwI8a-euwYQiJ3ZmAE%7C?hl=en',
#   'rating': 5.0,
#   'date': '3 months ago',
#   'iso_date': '2024-12-22T04:39:13Z',
#   'iso_date_of_last_edit': '2024-12-22T04:39:13Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUR2LVotajF3RRAB',
#   'user': {'name': 'Gregorio Romero',
#    'link': 'https://www.google.com/maps/contrib/112098814746311330828?hl=en',
#    'contributor_id': '112098814746311330828',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocLHpgY41df0IQVrXPPpM4TX9qM0taUCgrpmI6Q8PdaVnTSN1w=s120-c-rp-mo-ba3-br100',
#    'local_guide': True,
#    'reviews': 2,
#    'photos': 0},
#   'response': {'date': '3 months ago',
#    'iso_date': '2024-12-22T07:33:42Z',
#    'iso_date_of_last_edit': '2024-12-22T07:33:42Z',
#    'snippet': "Hello Gregorio Romero, thank you for the 5 star! We're committed to providing excellent customer service with every shopping experience! Thank you for taking the time to post a review!",
#    'extracted_snippet': {'original': "Hello Gregorio Romero, thank you for the 5 star! We're committed to providing excellent customer service with every shopping experience! Thank you for taking the time to post a review!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUR2LWJLekVBEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDv-bKzEA%7CCgwI_o-euwYQ4MX5_gE%7C?hl=en',
#   'rating': 5.0,
#   'date': '3 months ago',
#   'iso_date': '2024-12-22T03:31:10Z',
#   'iso_date_of_last_edit': '2024-12-22T03:31:10Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUR2LWJLekVBEAE',
#   'user': {'name': 'Praxedis Albarran',
#    'link': 'https://www.google.com/maps/contrib/102626539601839096394?hl=en',
#    'contributor_id': '102626539601839096394',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocIn26RaG6DupeE1xiDAawbuUn182-zL3cTv794FTeoAyjDK7A=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 7,
#    'photos': 0},
#   'response': {'date': '3 months ago',
#    'iso_date': '2024-12-22T07:33:42Z',
#    'iso_date_of_last_edit': '2024-12-22T07:33:42Z',
#    'snippet': "Hello Praxedis Albarran, thank you for sharing your experience with us and for the 5 star review! We're grateful for your feedback and hope to serve you again soon!",
#    'extracted_snippet': {'original': "Hello Praxedis Albarran, thank you for sharing your experience with us and for the 5 star review! We're grateful for your feedback and hope to serve you again soon!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUR2a2ZfR2FnEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDvkf_Gag%7CCgwI_JyauwYQoICJrwM%7C?hl=en',
#   'rating': 5.0,
#   'date': '3 months ago',
#   'iso_date': '2024-12-21T09:46:36Z',
#   'iso_date_of_last_edit': '2024-12-21T09:46:36Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUR2a2ZfR2FnEAE',
#   'user': {'name': 'Ivan Jakobsson',
#    'link': 'https://www.google.com/maps/contrib/106046628180950623079?hl=en',
#    'contributor_id': '106046628180950623079',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjW78eFnNfUMfexCpXmpUEnKSZe46xc_zXp0mK0yqkd0oAcYS-NgEQ=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 158,
#    'photos': 61},
#   'response': {'date': '3 months ago',
#    'iso_date': '2024-12-21T11:21:57Z',
#    'iso_date_of_last_edit': '2024-12-21T11:21:57Z',
#    'snippet': 'Hello Ivan Jakobsson, thank you for the 5 star review! Check out our mobile app for convenience and easy online shopping!\n',
#    'extracted_snippet': {'original': 'Hello Ivan Jakobsson, thank you for the 5 star review! Check out our mobile app for convenience and easy online shopping!\n'}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUR2anZiZU13EAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDvjvbeMw%7CCgwIn9-VuwYQ0LvtrwM%7C?hl=en',
#   'rating': 5.0,
#   'date': '3 months ago',
#   'iso_date': '2024-12-20T13:22:39Z',
#   'iso_date_of_last_edit': '2024-12-20T13:22:39Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUR2anZiZU13EAE',
#   'user': {'name': 'Christie Gaff',
#    'link': 'https://www.google.com/maps/contrib/110747483485613102171?hl=en',
#    'contributor_id': '110747483485613102171',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUM7dFyQkc6DUMxDwBjZHpdkclr4Cr3k1dlYOVSb2btL5oeveyT=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 0,
#    'photos': 2},
#   'response': {'date': '3 months ago',
#    'iso_date': '2024-12-21T11:21:58Z',
#    'iso_date_of_last_edit': '2024-12-21T11:21:58Z',
#    'snippet': 'Hello Christie Gaff, thank you for recognizing our dedication to providing excellent service! We appreciate your feedback and for posting a 5 star review!',
#    'extracted_snippet': {'original': 'Hello Christie Gaff, thank you for recognizing our dedication to providing excellent service! We appreciate your feedback and for posting a 5 star review!'}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUR4M1lMdUJBEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDx3YLuBA%7CCgwIk_yFuwYQuMWorQI%7C?hl=en',
#   'rating': 5.0,
#   'date': '4 months ago',
#   'iso_date': '2023-06-13T21:55:11Z',
#   'iso_date_of_last_edit': '2024-12-17T13:35:15Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUR4M1lMdUJBEAE',
#   'user': {'name': 'Dave Astin',
#    'link': 'https://www.google.com/maps/contrib/111296407874857938160?hl=en',
#    'contributor_id': '111296407874857938160',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUszxkUGglyygdHI-odVq2p8FCeDTRQCOQx3QJOoUshjEjP_PA=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 97,
#    'photos': 0}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNQN3RLVGJ3EAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICP7tKTbw%7CCgsIhpmNugYQgLOqFg%7C?hl=en',
#   'rating': 5.0,
#   'date': '4 months ago',
#   'iso_date': '2024-11-24T15:55:50Z',
#   'iso_date_of_last_edit': '2024-11-24T15:55:50Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUNQN3RLVGJ3EAE',
#   'user': {'name': 'White Love',
#    'link': 'https://www.google.com/maps/contrib/109417802613634876661?hl=en',
#    'contributor_id': '109417802613634876661',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocJUUQuNmBGw5fVZRfM5tg9GJt7cKbReOOESrV0r4LeBBy2v4w=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 0,
#    'photos': 0},
#   'response': {'date': '4 months ago',
#    'iso_date': '2024-11-25T05:56:16Z',
#    'iso_date_of_last_edit': '2024-11-25T05:56:16Z',
#    'snippet': "Hello White Love, thank you for choosing us for your grocery needs! We're thrilled to have made your grocery shopping experience enjoyable! ",
#    'extracted_snippet': {'original': "Hello White Love, thank you for choosing us for your grocery needs! We're thrilled to have made your grocery shopping experience enjoyable! "}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUQzc2JETVF3EAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgID3sbDMQw%7CCgsI4fffuQYQsND2Sw%7C?hl=en',
#   'rating': 1.0,
#   'date': '5 months ago',
#   'iso_date': '2024-11-16T01:56:49Z',
#   'iso_date_of_last_edit': '2024-11-16T01:56:49Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUQzc2JETVF3EAE',
#   'user': {'name': 'Cooperfam',
#    'link': 'https://www.google.com/maps/contrib/114728384607033004245?hl=en',
#    'contributor_id': '114728384607033004245',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjX_0aBd6wUPCgS7Juo_I_YsrsyOmED77UkaXKz9nYDrJ27srA1Byg=s120-c-rp-mo-ba3-br100',
#    'local_guide': True,
#    'reviews': 32,
#    'photos': 0},
#   'snippet': "It was 5:30pm  nov15, I'm standing at the Delhi I asked for the rest of the jojo's and when I accepted them I said thank you I appreciate it,  and the guy who was working the Delhi said (alright great). Wow!\nWhat happened to customer service?\nI felt that was extremely rude.  Even most strangers come back with something courteous to say.\nMaybe some management should have a talk with him on how to talk to customers.",
#   'extracted_snippet': {'original': "It was 5:30pm  nov15, I'm standing at the Delhi I asked for the rest of the jojo's and when I accepted them I said thank you I appreciate it,  and the guy who was working the Delhi said (alright great). Wow!\nWhat happened to customer service?\nI felt that was extremely rude.  Even most strangers come back with something courteous to say.\nMaybe some management should have a talk with him on how to talk to customers."},
#   'response': {'date': '5 months ago',
#    'iso_date': '2024-11-16T15:05:33Z',
#    'iso_date_of_last_edit': '2024-11-16T15:05:33Z',
#    'snippet': 'Hello Cooperfam, we’re sorry to hear about your experience with the service you received at the deli! Our team has been made aware of your concerns. If you’d like to provide more details about your experience or if you’d be interested in a follow-up, please reach out to us via the “Contact Us” page on our official website and provide us with your phone number and reference this Google review. Thank you.',
#    'extracted_snippet': {'original': 'Hello Cooperfam, we’re sorry to hear about your experience with the service you received at the deli! Our team has been made aware of your concerns. If you’d like to provide more details about your experience or if you’d be interested in a follow-up, please reach out to us via the “Contact Us” page on our official website and provide us with your phone number and reference this Google review. Thank you.'}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUQzOUxxVGpRRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgID39LqTjQE%7CCgsI3qTOuQYQ6NusZQ%7C?hl=en',
#   'rating': 5.0,
#   'date': '5 months ago',
#   'iso_date': '2024-11-12T17:37:34Z',
#   'iso_date_of_last_edit': '2024-11-12T17:37:34Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUQzOUxxVGpRRRAB',
#   'user': {'name': 'basman shaoo',
#    'link': 'https://www.google.com/maps/contrib/104794644020345940273?hl=en',
#    'contributor_id': '104794644020345940273',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocK26qmEWzVN92o-Al43zSjHoinODCpueXnj9QvG-VRSlq1-Gg=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 0,
#    'photos': 0},
#   'response': {'date': '5 months ago',
#    'iso_date': '2024-11-13T10:26:50Z',
#    'iso_date_of_last_edit': '2024-11-13T10:26:50Z',
#    'snippet': "Hello basman shaoo, thank you for sharing your experience with us and for the 5 star review! We're grateful for your feedback and hope to serve you again soon!",
#    'extracted_snippet': {'original': "Hello basman shaoo, thank you for sharing your experience with us and for the 5 star review! We're grateful for your feedback and hope to serve you again soon!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURYbGFXek9BEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDXlaWzOA%7CCgsIyfeEuQYQiKzJcg%7C?hl=en',
#   'rating': 4.0,
#   'date': '5 months ago',
#   'iso_date': '2024-10-29T19:47:21Z',
#   'iso_date_of_last_edit': '2024-10-29T19:47:21Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURYbGFXek9BEAE',
#   'user': {'name': 'Tanayut Somya',
#    'link': 'https://www.google.com/maps/contrib/116204680375702401662?hl=en',
#    'contributor_id': '116204680375702401662',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocLu59XLnAl0042CD0azqFbbTKoeoZ8FbxQshapPaHIFS5MTZhM=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 5,
#    'photos': 3},
#   'snippet': '- at night they will have food for sale\n- Their discount section is great\n- Staff are very nice\n- If you go late after ~10 pm, they closed most of the self-check out and the line will be super long, BUT there will be staff help you to check out.\n- Restroom is clean',
#   'extracted_snippet': {'original': '- at night they will have food for sale\n- Their discount section is great\n- Staff are very nice\n- If you go late after ~10 pm, they closed most of the self-check out and the line will be super long, BUT there will be staff help you to check out.\n- Restroom is clean'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURYdUppVXJRRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDXuJiUrQE%7CCgsI0YTmuAYQgJCZZQ%7C?hl=en',
#   'rating': 3.0,
#   'date': '5 months ago',
#   'iso_date': '2024-10-23T23:10:09Z',
#   'iso_date_of_last_edit': '2024-10-23T23:10:09Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURYdUppVXJRRRAB',
#   'user': {'name': 'DreadNaught 503',
#    'link': 'https://www.google.com/maps/contrib/105734962163383746564?hl=en',
#    'contributor_id': '105734962163383746564',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjWMCbpqwcNnfyBlOGlaemfgXaAYLydGCyV1yZ02977r7J0RgRMU=s120-c-rp-mo-ba2-br100',
#    'local_guide': True,
#    'reviews': 24,
#    'photos': 0},
#   'snippet': 'No diced tomatoes were stocked at this location.',
#   'extracted_snippet': {'original': 'No diced tomatoes were stocked at this location.'},
#   'response': {'date': '5 months ago',
#    'iso_date': '2024-10-23T23:26:47Z',
#    'iso_date_of_last_edit': '2024-10-23T23:26:47Z',
#    'snippet': 'This is concerning, and understand the frustration of not being able to shop for all the items you hope to get. Our research indicates that we do show sales of this item at your store. If you were unable to locate this item it is possible that either it was temporarily out of stock. We have directed your feedback to our proper personnel team for further review. If you have any other concerns, feel free to reach out to us on the Contact Us page on our website.',
#    'extracted_snippet': {'original': 'This is concerning, and understand the frustration of not being able to shop for all the items you hope to get. Our research indicates that we do show sales of this item at your store. If you were unable to locate this item it is possible that either it was temporarily out of stock. We have directed your feedback to our proper personnel team for further review. If you have any other concerns, feel free to reach out to us on the Contact Us page on our website.'}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURYbUtMY2tnRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDXmKLckgE%7CCgwI_v3kuAYQwPrWpwM%7C?hl=en',
#   'rating': 4.0,
#   'date': '5 months ago',
#   'iso_date': '2024-10-23T18:22:54Z',
#   'iso_date_of_last_edit': '2024-10-23T18:22:54Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURYbUtMY2tnRRAB',
#   'user': {'name': 'Bill Bann',
#    'link': 'https://www.google.com/maps/contrib/112990948844741655837?hl=en',
#    'contributor_id': '112990948844741655837',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUZOxyUawC16CmjYMJIoC048I-AFzsIeNEm0gmpjH0nKRMPbvqP=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 185,
#    'photos': 64},
#   'snippet': 'Grocery store',
#   'extracted_snippet': {'original': 'Grocery store'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUNYbDRHSDVRRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICXl4GH5QE%7CCgwIrcbZuAYQ0L2LigM%7C?hl=en',
#   'rating': 2.0,
#   'date': '5 months ago',
#   'iso_date': '2024-10-21T14:20:29Z',
#   'iso_date_of_last_edit': '2024-10-21T14:20:29Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUNYbDRHSDVRRRAB',
#   'user': {'name': 'Glenda Stowell',
#    'link': 'https://www.google.com/maps/contrib/112170981796753881468?hl=en',
#    'contributor_id': '112170981796753881468',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocK5SfGbE3f3d1Eybgu5PVe085kiic-z7dDtuTZgDa4gAviPJg=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 3,
#    'photos': 0}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUNYbHViTGVREAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICXlubLeQ%7CCgsIyrm9uAYQ8LnnFA%7C?hl=en',
#   'rating': 4.0,
#   'date': '6 months ago',
#   'iso_date': '2024-10-16T06:27:22Z',
#   'iso_date_of_last_edit': '2024-10-16T06:27:22Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUNYbHViTGVREAE',
#   'user': {'name': 'Aaron',
#    'link': 'https://www.google.com/maps/contrib/102422437721554807619?hl=en',
#    'contributor_id': '102422437721554807619',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjVvQfTlFwdqgcRvRMOlOg0XWldH-BFeCGlNA1GcWoL_K9h27Bg=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 35,
#    'photos': 6},
#   'response': {'date': '6 months ago',
#    'iso_date': '2024-10-16T23:37:20Z',
#    'iso_date_of_last_edit': '2024-10-16T23:37:20Z',
#    'snippet': "Hello Aaron, your 4 star review and positive feedback is greatly appreciated! We're committed to providing excellent customer service and products!",
#    'extracted_snippet': {'original': "Hello Aaron, your 4 star review and positive feedback is greatly appreciated! We're committed to providing excellent customer service and products!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUNYNHViUmtnRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICX4ubRkgE%7CCgwI0I-1uAYQoIfsrwE%7C?hl=en',
#   'rating': 5.0,
#   'date': '6 months ago',
#   'iso_date': '2024-10-14T16:33:20Z',
#   'iso_date_of_last_edit': '2024-10-14T16:33:20Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUNYNHViUmtnRRAB',
#   'user': {'name': 'Some Guy',
#    'link': 'https://www.google.com/maps/contrib/114004546701991672389?hl=en',
#    'contributor_id': '114004546701991672389',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUZmzigzN1sczpL0dj7P5h4fNQtkZM-Ac_9v5d3qrPgOfOrH2ZcTA=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 62,
#    'photos': 20},
#   'response': {'date': '6 months ago',
#    'iso_date': '2024-10-15T03:15:20Z',
#    'iso_date_of_last_edit': '2024-10-15T03:15:20Z',
#    'snippet': "Hello Some Guy, thank you for the 5 star! We're committed to providing excellent customer service with every shopping experience! Thank you for taking the time to post a review!",
#    'extracted_snippet': {'original': "Hello Some Guy, thank you for the 5 star! We're committed to providing excellent customer service with every shopping experience! Thank you for taking the time to post a review!"}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUQ3b0lhVHhRRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgID7oIaTxQE%7CCgwIkpSQtgYQiP_NnwE%7C?hl=en',
#   'rating': 5.0,
#   'date': '7 months ago',
#   'iso_date': '2024-08-20T03:14:26Z',
#   'iso_date_of_last_edit': '2024-08-20T03:14:26Z',
#   'images': ['https://lh3.googleusercontent.com/geougc-cs/AIHozJJqwuiWh0fXAdsJ0Y3WhkB2VO_JpCbBi3kYHni9HBozPoSW-lPgyrGk0ZdJEHhSp4FH4lhvkig2OQfSX47lP_t-veL_9ppPWkRbBWKWs7bp1QdB4inkh8VjcEnrelk95zD9K0iS'],
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUQ3b0lhVHhRRRAB',
#   'user': {'name': 'Marilyn Soriano',
#    'link': 'https://www.google.com/maps/contrib/102268240989482177958?hl=en',
#    'contributor_id': '102268240989482177958',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUmy_zZClwmigQzV0ldc_1RvMVUoSbnybQ0ZC4IlcG5elpBMbrx=s120-c-rp-mo-ba3-br100',
#    'local_guide': True,
#    'reviews': 27,
#    'photos': 50},
#   'snippet': 'Thank you to the bakery for doing this SpongeBob cake for my son!',
#   'extracted_snippet': {'original': 'Thank you to the bakery for doing this SpongeBob cake for my son!'}},
# ...
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUN4eS1MWmpBRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICxy-LZjAE%7CCgwIu-3AowYQgIys6gE%7C?hl=en',
#   'rating': 4.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-26T04:34:03Z',
#   'iso_date_of_last_edit': '2023-05-26T04:34:03Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUN4eS1MWmpBRRAB',
#   'user': {'name': 'Altaf Multani',
#    'link': 'https://www.google.com/maps/contrib/114991408070258337482?hl=en',
#    'contributor_id': '114991408070258337482',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocLHV06K9zJ2CW-dVvgtHJhqzte4jpqabSwQuWO76gFpXf61Mg=s120-c-rp-mo-ba3-br100',
#    'local_guide': True,
#    'reviews': 11,
#    'photos': 15}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUN4dGNQQ2F3EAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICxtcPCaw%7CCgsIqqevowYQ6K3eFA%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-22T20:42:18Z',
#   'iso_date_of_last_edit': '2023-05-22T20:42:18Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUN4dGNQQ2F3EAE',
#   'user': {'name': 'K S',
#    'link': 'https://www.google.com/maps/contrib/104485671366657775870?hl=en',
#    'contributor_id': '104485671366657775870',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUlAsI2-syOvsjlzZ0wR6TvuXy0C8h72lHXssKU-qEeKoCEeGuF6A=s120-c-rp-mo-br100',
#    'reviews': 5,
#    'photos': 0},
#   'snippet': 'The floral department employees are amazing and super helpful!',
#   'extracted_snippet': {'original': 'The floral department employees are amazing and super helpful!'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUN4dGZMbm13RRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICxtfLnmwE%7CCgwIgfauowYQuKWO1QI%7C?hl=en',
#   'rating': 4.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-22T18:56:53Z',
#   'iso_date_of_last_edit': '2023-05-22T18:57:05Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUN4dGZMbm13RRAB',
#   'user': {'name': 'Logan Ramaeker',
#    'link': 'https://www.google.com/maps/contrib/112365372930453209740?hl=en',
#    'contributor_id': '112365372930453209740',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocKofXUbEeYY0VBVTxgz1nrFKlICfJ1qj15IW4rbUSLEAEZmow=s120-c-rp-mo-br100',
#    'reviews': 37,
#    'photos': 3},
#   'snippet': 'The store itself is nice and put together very nice. The only reason for 4 star is the parking lot here is horrible. I try to avoid at all costs.',
#   'extracted_snippet': {'original': 'The store itself is nice and put together very nice. The only reason for 4 star is the parking lot here is horrible. I try to avoid at all costs.'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUN4Z2ZmcDVRRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICxgffp5QE%7CCgwI7a2bowYQkJLzhAI%7C?hl=en',
#   'rating': 1.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-19T01:21:06Z',
#   'iso_date_of_last_edit': '2023-05-19T01:54:53Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUN4Z2ZmcDVRRRAB',
#   'user': {'name': 'Jaeden Childers',
#    'link': 'https://www.google.com/maps/contrib/101531527837248892097?hl=en',
#    'contributor_id': '101531527837248892097',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjXz_Zk-VMllcAWigDow3l7WDeJKCqG2vpAIzLHYc3rGovcvle8=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 43,
#    'photos': 19},
#   'snippet': "Safeway, I regret to say that my previous rating of two stars was far too generous. Upon further reflection, I must downgrade it to a dismal one star. Let's talk about those noodles of yours. They were dry to the point where they seemed lifeless, as if they had perished long before reaching the serving booth. It's baffling how something so parched and inedible could even be considered suitable for human consumption. Safeway, you've managed to achieve the near-impossible feat of creating noodles that are almost physically impossible to consume. It's a disappointment beyond measure. I cannot in good conscience recommend anyone subject themselves to such a culinary tragedy. One star is the best I can offer, and even that feels generous. Let's have a little chat. I stopped by your store with high hopes of grabbing a free cookie from the desert/cake area, but to my disappointment, there was no worker in sight. No free cookie for me, I suppose. Now, let's address the elephant in the room - there are way too many sweets around. It's like a sugar overload in there, and for someone like me who prefers a balanced diet, it can be overwhelming. However, I must give credit where it's due. Safeway does have a decent selection of protein goods, which is a saving grace for those looking to get their gains. So, I'll give you 1 star for that, but Safeway, you've got some room for improvement when it comes to your bakery section and the excessive sweetness in the store.\n\nSincerely,\nJaeden Childers.",
#   'extracted_snippet': {'original': "Safeway, I regret to say that my previous rating of two stars was far too generous. Upon further reflection, I must downgrade it to a dismal one star. Let's talk about those noodles of yours. They were dry to the point where they seemed lifeless, as if they had perished long before reaching the serving booth. It's baffling how something so parched and inedible could even be considered suitable for human consumption. Safeway, you've managed to achieve the near-impossible feat of creating noodles that are almost physically impossible to consume. It's a disappointment beyond measure. I cannot in good conscience recommend anyone subject themselves to such a culinary tragedy. One star is the best I can offer, and even that feels generous. Let's have a little chat. I stopped by your store with high hopes of grabbing a free cookie from the desert/cake area, but to my disappointment, there was no worker in sight. No free cookie for me, I suppose. Now, let's address the elephant in the room - there are way too many sweets around. It's like a sugar overload in there, and for someone like me who prefers a balanced diet, it can be overwhelming. However, I must give credit where it's due. Safeway does have a decent selection of protein goods, which is a saving grace for those looking to get their gains. So, I'll give you 1 star for that, but Safeway, you've got some room for improvement when it comes to your bakery section and the excessive sweetness in the store.\n\nSincerely,\nJaeden Childers."},
#   'response': {'date': 'a year ago',
#    'iso_date': '2023-05-19T01:45:26Z',
#    'iso_date_of_last_edit': '2023-05-19T01:45:26Z',
#    'snippet': 'Hello Jaeden! We sincerely apologize for missing the mark with our Bakery! We take immense pride in offering quality products, and will notify Leadership! If you would like to be personally contacted, please visit us on our site to chat with us or reach out on our Contact Us page. Thank you.',
#    'extracted_snippet': {'original': 'Hello Jaeden! We sincerely apologize for missing the mark with our Bakery! We take immense pride in offering quality products, and will notify Leadership! If you would like to be personally contacted, please visit us on our site to chat with us or reach out on our Contact Us page. Thank you.'}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUN4Z2VERDBBRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICxgeDD0AE%7CCgwImauaowYQoNTksQM%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-18T21:10:23Z',
#   'iso_date_of_last_edit': '2023-05-18T21:16:09Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUN4Z2VERDBBRRAB',
#   'user': {'name': 'Antonia Barron',
#    'link': 'https://www.google.com/maps/contrib/105360486188004917004?hl=en',
#    'contributor_id': '105360486188004917004',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjVSegvAFQd_cEvvkJq0C-qiLr3QVaVJapsKmdcDgngKmxLlHG0I=s120-c-rp-mo-ba5-br100',
#    'local_guide': True,
#    'reviews': 135,
#    'photos': 808},
#   'snippet': "This Safeway didn't have Open Nature Salami one dollar coin size packs so I had to buy the smaller size salami instead of what I'm used to of all I walked out with grocerys. I prefer here because the Organic & Natural potential purchases are lower than Whole Foods and Natural Grocers. Thank God for this place.",
#   'extracted_snippet': {'original': "This Safeway didn't have Open Nature Salami one dollar coin size packs so I had to buy the smaller size salami instead of what I'm used to of all I walked out with grocerys. I prefer here because the Organic & Natural potential purchases are lower than Whole Foods and Natural Grocers. Thank God for this place."}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUN4OXNpWEV3EAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICx9siXEw%7CCgwI8t-SowYQ-PGY3gI%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-17T10:44:02Z',
#   'iso_date_of_last_edit': '2023-05-17T10:44:02Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUN4OXNpWEV3EAE',
#   'user': {'name': 'Butch Littke',
#    'link': 'https://www.google.com/maps/contrib/106820334383431091542?hl=en',
#    'contributor_id': '106820334383431091542',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUrlHzMAhXq8YqPOC7UI4hbSBCBUrpsvD2C15uTKWZgkhj9EYk=s120-c-rp-mo-ba2-br100',
#    'local_guide': True,
#    'reviews': 12,
#    'photos': 2}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUN4LXB1N2F3EAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICx-pu7aw%7CCgwIyLGMowYQ6O_FkgE%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-16T05:46:48Z',
#   'iso_date_of_last_edit': '2023-05-16T05:46:48Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUN4LXB1N2F3EAE',
#   'user': {'name': 'Barb Yanoshek',
#    'link': 'https://www.google.com/maps/contrib/115309719728522594023?hl=en',
#    'contributor_id': '115309719728522594023',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjXH11BMfPNW2VKDMJcg3gE-ugKO5Pdt5JjS44xvQ0npkulln72Jlg=s120-c-rp-mo-ba5-br100',
#    'local_guide': True,
#    'reviews': 274,
#    'photos': 101},
#   'snippet': 'The clerk allowed me discounts when I could not locate my Carrs/Safeway membership card.',
#   'extracted_snippet': {'original': 'The clerk allowed me discounts when I could not locate my Carrs/Safeway membership card.'}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUN4eXVINF9nRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICxyuH4_gE%7CCgsIl9GGowYQyPKuCw%7C?hl=en',
#   'rating': 3.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-15T03:35:51Z',
#   'iso_date_of_last_edit': '2023-05-15T03:35:51Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUN4eXVINF9nRRAB',
#   'user': {'name': 'Patti Lamb',
#    'link': 'https://www.google.com/maps/contrib/104036300460827056292?hl=en',
#    'contributor_id': '104036300460827056292',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocK_ESyqEjskemekJ0PuNRp2d64E_uyAqEYyY45UDFhyo0ndmg=s120-c-rp-mo-br100',
#    'reviews': 83,
#    'photos': 0},
#   'snippet': 'Hard to find items. They move items way too often.',
#   'extracted_snippet': {'original': 'Hard to find items. They move items way too often.'},
#   'response': {'date': 'a year ago',
#    'iso_date': '2023-05-15T17:15:58Z',
#    'iso_date_of_last_edit': '2023-05-15T17:15:58Z',
#    'snippet': "We are sorry to hear about your experience with the layout at our store, Mark! Our customer's voices are greatly relied on to ensure we are providing satisfactory service. Leadership has been made aware of your concerns about the layout. We thank you for shopping with us! ",
#    'extracted_snippet': {'original': "We are sorry to hear about your experience with the layout at our store, Mark! Our customer's voices are greatly relied on to ensure we are providing satisfactory service. Leadership has been made aware of your concerns about the layout. We thank you for shopping with us! "}}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUN4ek1xcFdREAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICxzMqpWQ%7CCgwIg5f3ogYQ8JawwAI%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-12T05:15:47Z',
#   'iso_date_of_last_edit': '2023-05-12T05:15:47Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUN4ek1xcFdREAE',
#   'user': {'name': 'April Bryant',
#    'link': 'https://www.google.com/maps/contrib/115974571079976209576?hl=en',
#    'contributor_id': '115974571079976209576',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjXStDbfBylemXw22-8ZXMAbdx6snDXqwSSRViWhFmZZOTc485Zy=s120-c-rp-mo-ba2-br100',
#    'local_guide': True,
#    'reviews': 8,
#    'photos': 2},
#   'snippet': "Place is clean. Shelves are all nice and neatly organized. Staff is kind and helpful. Except 1 but the place can't be perfect. Self check out isn't the best when they have that 1  certain employee working. But again whatcha gonna do? Push her down a Hil ?",
#   'extracted_snippet': {'original': "Place is clean. Shelves are all nice and neatly organized. Staff is kind and helpful. Except 1 but the place can't be perfect. Self check out isn't the best when they have that 1  certain employee working. But again whatcha gonna do? Push her down a Hil ?"}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSUN4akx1ODZnRRAB!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICxjLu86gE%7CCgsI6s72ogYQ-MSNQw%7C?hl=en',
#   'rating': 4.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-12T02:41:46Z',
#   'iso_date_of_last_edit': '2023-05-12T02:41:46Z',
#   'source': 'Google',
#   'review_id': 'ChdDSUhNMG9nS0VJQ0FnSUN4akx1ODZnRRAB',
#   'user': {'name': 'Denny Moyer',
#    'link': 'https://www.google.com/maps/contrib/104829276973792500269?hl=en',
#    'contributor_id': '104829276973792500269',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocKv9DkFVrPX2IPzSr0TwodhNWvO5DaSy3-ttTNXdRBjSMut3w=s120-c-rp-mo-ba2-br100',
#    'local_guide': True,
#    'reviews': 17,
#    'photos': 0}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSUN4OE8yTUtBEAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgICx8O2MKA%7CCgwI8sPnogYQsKX8rAI%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-09T06:02:26Z',
#   'iso_date_of_last_edit': '2023-05-09T06:02:26Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSUN4OE8yTUtBEAE',
#   'user': {'name': 'Baby Rey',
#    'link': 'https://www.google.com/maps/contrib/105412335514763127627?hl=en',
#    'contributor_id': '105412335514763127627',
#    'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocIEaS9qgGlZlcZ9YDX7m3HyijSiT1dSU6x7NfZ6GcEq4rlHNw=s120-c-rp-mo-br100',
#    'local_guide': True,
#    'reviews': 7,
#    'photos': 1}},
#  {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURSMThHQWVREAE!2m1!1s0x0:0x524bf6f735f45390!3m1!1s2@1:CIHM0ogKEICAgIDR18GAeQ%7CCgwIp_XVogYQ4JvpiwE%7C?hl=en',
#   'rating': 5.0,
#   'date': 'a year ago',
#   'iso_date': '2023-05-05T21:52:39Z',
#   'iso_date_of_last_edit': '2023-05-05T21:52:39Z',
#   'source': 'Google',
#   'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURSMThHQWVREAE',
#   'user': {'name': 'Linda Thrasher',
#    'link': 'https://www.google.com/maps/contrib/111329228638039884133?hl=en',
#    'contributor_id': '111329228638039884133',
#    'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjXgLxRewlrztdlRp4cBwf8pTNr5Iru2J1TG5Ojt3fu0GolnUSQ=s120-c-rp-mo-ba4-br100',
#    'local_guide': True,
#    'reviews': 101,
#    'photos': 3},
#   'snippet': 'Always love should at this Safeway',
#   'extracted_snippet': {'original': 'Always love should at this Safeway'}}]

# %%
def analyze_keyword_mentions(reviews, keyword_string):
    """
    Analyzes keyword mentions in review text (case-insensitive).
    - Each keyword is only counted once per review.
    - Keyword must be matched as a whole word (not inside another word).
    """
    keywords = [kw.strip().lower() for kw in keyword_string.split(",") if kw.strip()]
    total_reviews = len(reviews)

    keyword_counts = {kw: 0 for kw in keywords}
    reviews_with_any_keyword = 0
    non_empty_reviews = 0

    for review in reviews:
        text = (review.get("snippet") or "").strip().lower()
        if not text:
            continue

        non_empty_reviews += 1
        matched_any = False

        for kw in keywords:
            pattern = r'\b' + re.escape(kw) + r'\b'
            if re.search(pattern, text):
                keyword_counts[kw] += 1
                matched_any = True

        if matched_any:
            reviews_with_any_keyword += 1

    empty_reviews = total_reviews - non_empty_reviews

    raw_percentages = {
        kw: (count / total_reviews * 100) if total_reviews else 0
        for kw, count in keyword_counts.items()
    }
    normalized_percentages = {
        kw: (count / non_empty_reviews * 100) if non_empty_reviews else 0
        for kw, count in keyword_counts.items()
    }

    return {
        "keyword_counts": keyword_counts,
        "raw_percentages": raw_percentages,
        "normalized_percentages": normalized_percentages,
        "reviews_with_any_keyword": reviews_with_any_keyword,
        "raw_any_percentage": (reviews_with_any_keyword / total_reviews * 100) if total_reviews else 0,
        "norm_any_percentage": (reviews_with_any_keyword / non_empty_reviews * 100) if non_empty_reviews else 0,
        "empty_count": empty_reviews,
        "empty_percentage": (empty_reviews / total_reviews * 100) if total_reviews else 0,
        "total": total_reviews,
        "non_empty": non_empty_reviews,
    }

# %%
# Analyze keywords
keyword_string = "chill, happy,delicious, stinky, bread"
stats = analyze_keyword_mentions(reviews, keyword_string)

print(f"\n🔍 Total reviews: {stats['total']}")
print(f"📝 Reviews with no text: {stats['empty_count']}")
print(f"📝 Non-empty reviews: {stats['non_empty']}")

print("\n📊 Keyword Mentions (Raw %):")
for kw in stats['keyword_counts']:
    print(f"- {kw}: {stats['keyword_counts'][kw]} ({stats['raw_percentages'][kw]:.1f}%)")

print("\n📊 Keyword Mentions (Normalized to non-empty reviews):")
for kw in stats['keyword_counts']:
    print(f"- {kw}: {stats['normalized_percentages'][kw]:.1f}%")

print(f"\n📈 % of all reviews mentioning any keyword: {stats['raw_any_percentage']:.1f}%")
print(f"📈 % of non-empty reviews mentioning any keyword: {stats['norm_any_percentage']:.1f}%")
# Out:
# 🔍 Total reviews: 100
# 📝 Reviews with no text: 44
# 📝 Non-empty reviews: 56
#
# 📊 Keyword Mentions (Raw %):
# - chill: 0 (0.0%)
# - happy: 1 (1.0%)
# - delicious: 0 (0.0%)
# - stinky: 0 (0.0%)
# - bread: 1 (1.0%)
#
# 📊 Keyword Mentions (Normalized to non-empty reviews):
# - chill: 0.0%
# - happy: 1.8%
# - delicious: 0.0%
# - stinky: 0.0%
# - bread: 1.8%
#
# 📈 % of all reviews mentioning any keyword: 2.0%
# 📈 % of non-empty reviews mentioning any keyword: 3.6%
